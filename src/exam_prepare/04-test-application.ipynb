# %%
from application import ExamGeneratorInput
from application import ExamGeneratorService
# Out:
# c:\Users\Admin\anaconda3\envs\self-study\lib\site-packages\pydantic\_internal\_fields.py:128: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
exam_gen_service = ExamGeneratorService()

# %%
import pprint

response = exam_gen_service.process(
    ExamGeneratorInput(
        exam_type="test_15m",
        number_multiplechoice=3,
        number_essay=2,
        subject="Toán",
        level_class="Grade 10",
        chapters=["Chương 1", "Chương 2"],
        lang="vi",
    )
)

# %%
pprint.pprint(response.exam_question)
# Out:
# {'content': '```markdown\n'
#             '# Tóm tắt nội dung chi tiết các chương 1 và 2 môn Toán lớp 10\n'
#             '\n'
#             '## Chương 1: Vectơ\n'
#             '\n'
#             '### 1. Định nghĩa và ký hiệu\n'
#             '\n'
#             '- **Vectơ**: Là đoạn thẳng có hướng, được xác định bởi điểm đầu '
#             'và điểm cuối. Ký hiệu: \n'
#             '- **Vectơ không**: Vectơ có điểm đầu trùng với điểm cuối, ký '
#             'hiệu: \n'
#             '\n'
#             '### 2. Độ dài và phương của vectơ\n'
#             '\n'
#             '- **Độ dài vectơ**: Khoảng cách giữa điểm đầu và điểm cuối, ký '
#             'hiệu: \n'
#             '- **Hai vectơ cùng phương**: Hai vectơ có giá song song hoặc '
#             'trùng nhau.\n'
#             '\n'
#             '### 3. Phép toán với vectơ\n'
#             '\n'
#             '- **Cộng và hiệu vectơ**: Áp dụng quy tắc ba điểm để xác định '
#             'tổng và hiệu của hai vectơ.\n'
#             '- **Vectơ đối**: Vectơ có cùng độ dài và ngược hướng với vectơ '
#             'cho trước.\n'
#             '\n'
#             '### 4. Độ dài tổng và hiệu của hai vectơ\n'
#             '\n'
#             '- **Độ dài tổng và hiệu**: Sử dụng định lý hình bình hành và định '
#             'lý cosin để tính độ dài của tổng và hiệu hai vectơ.\n'
#             '\n'
#             '## Chương 2: Hàm số\n'
#             '\n'
#             '### 1. Hàm số bậc nhất\n'
#             '\n'
#             '- **Định nghĩa**: Hàm số có dạng: \n'
#             '- **Sự biến thiên**: Xác định miền xác định và tính chất đồng '
#             'biến, nghịch biến dựa trên hệ số góc a.\n'
#             '- **Đồ thị**: Là đường thẳng có hệ số góc a, cắt trục hoành tại '
#             'và trục tung tại .\n'
#             '\n'
#             '### 2. Hàm số bậc hai\n'
#             '\n'
#             '- **Định nghĩa**: Hàm số có dạng: \n'
#             '- **Sự biến thiên**: Xác định miền xác định và tính chất đồng '
#             'biến, nghịch biến dựa trên hệ số a.\n'
#             '- **Đồ thị**: Là parabol, bề lõm hướng lên trên khi a > 0 và '
#             'hướng xuống dưới khi a < 0.\n'
#             '```\n'
#             ' ',
#  'questions': {'exam_type': 'test_15m',
#                'level_class': 10,
#                'questions': {'essay': [{'expected_answer': 'Vectơ là đoạn '
#                                                            'thẳng có hướng, '
#                                                            'được xác định bởi '
#                                                            'điểm đầu và điểm '
#                                                            'cuối. Các phép '
#                                                            'toán với vectơ bao '
#                                                            'gồm cộng và hiệu '
#                                                            'vectơ, tích của '
#                                                            'một số với vectơ, '
#                                                            'và tích vô hướng '
#                                                            'của hai vectơ. Ứng '
#                                                            'dụng của vectơ '
#                                                            'trong thực tế như '
#                                                            'biểu diễn lực '
#                                                            'trong vật lý, '
#                                                            'chuyển động trong '
#                                                            'không gian, và các '
#                                                            'bài toán hình học '
#                                                            'phẳng.',
#                                         'question': 'Hãy giải thích khái niệm '
#                                                     'vectơ, các phép toán với '
#                                                     'vectơ và ứng dụng của '
#                                                     'chúng trong thực tế.'},
#                                        {'expected_answer': 'Hàm số bậc hai y = '
#                                                            'ax² + bx + c có đồ '
#                                                            'thị là parabol. '
#                                                            'Miền xác định của '
#                                                            'hàm số là tập hợp '
#                                                            'tất cả các giá trị '
#                                                            'x thực. Tính chất '
#                                                            'đồng biến, nghịch '
#                                                            'biến của hàm số '
#                                                            'phụ thuộc vào hệ '
#                                                            'số a: nếu a > 0, '
#                                                            'hàm số đồng biến '
#                                                            'trên (-∞; -b/2a) '
#                                                            'và nghịch biến '
#                                                            'trên (-b/2a; +∞); '
#                                                            'nếu a < 0, hàm số '
#                                                            'nghịch biến trên '
#                                                            '(-∞; -b/2a) và '
#                                                            'đồng biến trên '
#                                                            '(-b/2a; +∞).',
#                                         'question': 'Phân tích sự biến thiên '
#                                                     'và đồ thị của hàm số bậc '
#                                                     'hai y = ax² + bx + c, nêu '
#                                                     'rõ cách xác định miền xác '
#                                                     'định và tính chất đồng '
#                                                     'biến, nghịch biến của hàm '
#                                                     'số.'}],
#                              'multiple_choice': [{'answer': 'A',
#                                                   'options': ['A. Đoạn thẳng '
#                                                               'AB',
#                                                               'B. Đoạn thẳng '
#                                                               'CD',
#                                                               'C. Đoạn thẳng '
#                                                               'EF',
#                                                               'D. Đoạn thẳng '
#                                                               'GH'],
#                                                   'question': 'Đoạn thẳng nào '
#                                                               'sau đây là '
#                                                               'vectơ không?'},
#                                                  {'answer': 'B',
#                                                   'options': ['A. Đồ thị cắt '
#                                                               'trục hoành tại '
#                                                               'điểm âm',
#                                                               'B. Đồ thị cắt '
#                                                               'trục hoành tại '
#                                                               'điểm dương',
#                                                               'C. Đồ thị cắt '
#                                                               'trục tung tại '
#                                                               'điểm âm',
#                                                               'D. Đồ thị cắt '
#                                                               'trục tung tại '
#                                                               'điểm dương'],
#                                                   'question': 'Khi hệ số góc a '
#                                                               'của hàm số bậc '
#                                                               'nhất y = ax + b '
#                                                               'là dương, đồ '
#                                                               'thị của hàm số '
#                                                               'có đặc điểm '
#                                                               'gì?'},
#                                                  {'answer': 'B',
#                                                   'options': ['A. Đường thẳng',
#                                                               'B. Parabol',
#                                                               'C. Hình tròn',
#                                                               'D. Hình elip'],
#                                                   'question': 'Đồ thị của hàm '
#                                                               'số bậc hai y = '
#                                                               'ax² + bx + c có '
#                                                               'dạng gì?'}]},
#                'subject': 'Toán'}}
